# %% [markdown]
# <a href="https://colab.research.google.com/github/Filoferro03/ActionSpottingCalcio/blob/main/TesiActionSpottingCalcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/OpenSportsLab/OSL-ActionSpotting.git
# %cd OSL-ActionSpotting
# Out:
# Cloning into 'OSL-ActionSpotting'...
# remote: Enumerating objects: 2595, done.
# remote: Counting objects: 100% (451/451), done.
# remote: Compressing objects: 100% (297/297), done.
# remote: Total 2595 (delta 203), reused 308 (delta 145), pack-reused 2144 (from 1)
# Receiving objects: 100% (2595/2595), 130.65 MiB | 18.04 MiB/s, done.
# Resolving deltas: 100% (1594/1594), done.
# /content/OSL-ActionSpotting

# %%
# !pip install -r requirements.txt
# Out:
# ...
# WARNING: typer 0.15.3 does not provide the extra 'all'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 19.1 MB/s eta 0:00:00
# ...

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/OSL-ActionSpotting
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
# ...
# WARNING: typer 0.15.3 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 35.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Running setup.py develop for oslactionspotting
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.device_count())
    print(torch.cuda.current_device())
    print(torch.cuda.get_device_name(0))
# Out:
# 2.6.0+cu124
# True
# 1
# 0
# Tesla T4

# %%
# !pip install SoccerNet

# %%
# Importa la libreria drive se non l'hai già fatto
from google.colab import drive

# !rm -rf /content/gdrive/*

drive.mount('/content/gdrive')

# Dopo il montaggio, puoi ricreare la tua cartella per i dati se necessario
# !mkdir -p /content/gdrive/MyDrive/datasets/SoccerNet
# Out:
# Mounted at /content/gdrive

# %%
import os
from SoccerNet.Downloader import SoccerNetDownloader

# Inizializza il downloader, specificando il percorso dove salvare i dati
mySoccerNetDownloader = SoccerNetDownloader(LocalDirectory="/content/gdrive/MyDrive/datasets/SoccerNet")

mySoccerNetDownloader.downloadDataTask(task="spotting-OSL", split=["train", "valid", "test"], version="ResNET_PCA512")
# Out:
# /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/train.zip already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/valid.zip already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/test.zip already exists

# %%
mySoccerNetDownloader.downloadGames(files=["Labels-v2.json"], split=["train", "valid", "test"])
# Out:
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/Labels-v2.json already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal/Labels-v2.json already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Swansea 2 - 1 Manchester United/Labels-v2.json already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-22 - 19-15 Southampton 0 - 2 Liverpool/Labels-v2.json already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2015-2016/2015-08-08 - 19-30 Chelsea 2 - 2 Swansea/Labels-v2.json already exists
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2015-2016/2015-08-29 - 17-00 Chelsea 1 - 2 Crystal Palace/Labels-v2.json already exists
# ...

# %%
# Crea la cartella per salvare i JSON generati da OSL-ActionSpotting, se non esiste
# !mkdir -p /content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations

# !python /content/OSL-ActionSpotting/tools/createJson/createjson_soccernet.py --soccernet_root_dir /content/gdrive/MyDrive/datasets/SoccerNet --save_dir /content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations

# %%
print("Listing contents of SoccerNet base directory:")
# !ls -R /content/gdrive/MyDrive/datasets/SoccerNet/

print("\nListing contents of a specific game directory (example):")
# Sostituisci con una delle partite che dovrebbe avere Labels-v2.json
# !ls -R /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21\ -\ 18-00\ Chelsea\ 1\ -\ 1\ Burnley/
# Out:
# Listing contents of SoccerNet base directory:
# /content/gdrive/MyDrive/datasets/SoccerNet/:
# england_epl		      france_ligue-1	  italy_serie-a  spotting-OSL
# europe_uefa-champions-league  germany_bundesliga  spain_laliga
#
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl:
# 2014-2015  2015-2016  2016-2017
#
# /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015:
# '2015-02-21 - 18-00 Chelsea 1 - 1 Burnley'
# '2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal'
# '2015-02-21 - 18-00 Swansea 2 - 1 Manchester United'
# '2015-02-22 - 19-15 Southampton 0 - 2 Liverpool'
# '2015-04-11 - 19-30 Burnley 0 - 1 Arsenal'
# '2015-05-17 - 18-00 Manchester United 1 - 1 Arsenal'
#
# '/content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley':
# Labels-v2.json
#
# '/content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Crystal Palace 1 - 2 Arsenal':
# Labels-v2.json
#
# ...

# %%
import zipfile
import os

# Percorso della cartella che contiene i file zip delle features
base_zip_folder = "/content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/"
# Percorso di destinazione dove verranno decompressi i contenuti.
# Questo deve essere la stessa cartella SOCCERNET_ORIG_FOLDER nello script createjson_soccernet.py
output_extract_path = "/content/gdrive/MyDrive/datasets/SoccerNet/"

# Lista dei file zip da decomprimere
zip_files_to_unzip = [
    os.path.join(base_zip_folder, "train.zip"),
    os.path.join(base_zip_folder, "valid.zip"),
    os.path.join(base_zip_folder, "test.zip") # CORREZIONE QUI: da 'base_zip_path' a 'base_zip_folder'
]

for zip_file_path in zip_files_to_unzip:
    if os.path.exists(zip_file_path):
        print(f"Decompressing {zip_file_path}...")
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            # Decomprimi tutto il contenuto nel percorso radice di SoccerNet
            # Questo dovrebbe creare le sottocartelle delle partite e i file .npy al loro interno
            zip_ref.extractall(output_extract_path)
        print(f"Finished decompressing {zip_file_path}")
    else:
        print(f"Zip file not found: {zip_file_path}. Make sure you downloaded them!")

print("\nDecompression complete. Verifying structure for features...")
# Verifica che i file .npy siano ora nelle cartelle delle partite
# Sostituisci con una delle partite per cui hai scaricato le features
# !ls -R /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21\ -\ 18-00\ Chelsea\ 1\ -\ 1\ Burnley/
# Out:
# Decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/train.zip...
# Finished decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/train.zip
# Decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/valid.zip...
# Finished decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/valid.zip
# Decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/test.zip...
# Finished decompressing /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/test.zip
#
# Decompression complete. Verifying structure for features...
# '/content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/':
# Labels-v2.json

# %%
# Crea la cartella per salvare i JSON generati da OSL-ActionSpotting, se non esiste
# !mkdir -p /content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations

# Esegui lo script createjson_soccernet.py
# Le variabili SOCCERNET_ORIG_FOLDER e SOCCERNET_ZIP_FOLDER nel file dovrebbero puntare ai percorsi corretti.
# !python /content/OSL-ActionSpotting/tools/createJson/createjson_soccernet.py

# %%
print("Listing generated OSL-ActionSpotting JSONs:")
# !ls -lh /content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations/
# Out:
# Listing generated OSL-ActionSpotting JSONs:
# total 27M
# -rw------- 1 root root 5.5M Jun  5 13:28 test.json
# -rw------- 1 root root  17M Jun  5 13:27 train.json
# -rw------- 1 root root 5.2M Jun  5 13:28 valid.json

# %%
# !mkdir -p /content/OSL-ActionSpotting/configs/my_experiments
# !cp /content/OSL-ActionSpotting/configs/learnablepooling/json_netvlad++_resnetpca512.py /content/OSL-ActionSpotting/configs/my_experiments/my_thesis_netvlad_config.py

# %%
# !pip install --extra-index-url https://pypi.nvidia.com/ nvidia-dali-cuda120
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.9/444.9 MB 48.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 171.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 200.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 188.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 150.0 MB/s eta 0:00:00
# ...

# %%
print("Starting model training...")
# !python /content/OSL-ActionSpotting/tools/train.py /content/OSL-ActionSpotting/configs/my_experiments/my_thesis_netvlad_config.py
# Out:
# Starting model training...
# 2025-06-05 13:55:44,605 [MainThread  ] [INFO ]  Checking configs files
# ...

# %%
import json
import os

json_path = "/content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations/train.json"

if os.path.exists(json_path):
    print(f"Content of {json_path}:")
    with open(json_path, 'r') as f:
        data = json.load(f)
        # Stampa solo le prime 5 voci video per non riempire l'output
        for i, video_entry in enumerate(data.get("videos", [])):
            if i >= 5:
                break
            print(f"Video {i+1}:")
            print(f"  path_features: {video_entry.get('path_features', 'N/A')}")
            print(f"  path_video: {video_entry.get('path_video', 'N/A')}")
            print(f"  annotations count: {len(video_entry.get('annotations', []))}")
        print(f"\nTotal videos in JSON: {len(data.get('videos', []))}")
else:
    print(f"JSON file not found: {json_path}")
# Out:
# Content of /content/gdrive/MyDrive/datasets/SoccerNet_OSL_Annotations/train.json:
# Video 1:
#   path_features: england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/1_ResNET_TF2_PCA512.npy
#   path_video: england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/1_224p.mkv
#   annotations count: 97
# Video 2:
#   path_features: england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/2_ResNET_TF2_PCA512.npy
#   path_video: england_epl/2014-2015/2015-02-21_-_18-00_Chelsea_1_-_1_Burnley/2_224p.mkv
#   annotations count: 93
# Video 3:
#   path_features: england_epl/2014-2015/2015-02-21_-_18-00_Crystal_Palace_1_-_2_Arsenal/1_ResNET_TF2_PCA512.npy
#   path_video: england_epl/2014-2015/2015-02-21_-_18-00_Crystal_Palace_1_-_2_Arsenal/1_224p.mkv
#   annotations count: 113
# Video 4:
#   path_features: england_epl/2014-2015/2015-02-21_-_18-00_Crystal_Palace_1_-_2_Arsenal/2_ResNET_TF2_PCA512.npy
# ...

# %%
# Sostituisci "YOUR_RELATIVE_FEATURE_PATH" con uno dei path_features dal tuo JSON
# Esempio: "england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_ResNET_TF2_PCA512.npy"
relative_feature_path = "england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_ResNET_TF2_PCA512.npy"

# La cartella radice delle features specificata nel tuo config (data_root)
feature_root = "/content/gdrive/MyDrive/datasets/SoccerNet"

full_feature_path = os.path.join(feature_root, relative_feature_path)

print(f"Checking for existence of: {full_feature_path}")
if os.path.exists(full_feature_path):
    print("File exists! (This is good)")
    # Puoi anche verificare la dimensione del file per assicurarti che non sia vuoto
    print(f"File size: {os.path.getsize(full_feature_path)} bytes")
else:
    print("File NOT found! (This is the problem)")
    # Se non trovato, elenca i contenuti della cartella padre per vedere cosa c'è
    parent_dir = os.path.dirname(full_feature_path)
    print(f"Listing contents of parent directory: {parent_dir}")
    # !ls -l "{parent_dir}"
# Out:
# Checking for existence of: /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley/1_ResNET_TF2_PCA512.npy
# File NOT found! (This is the problem)
# Listing contents of parent directory: /content/gdrive/MyDrive/datasets/SoccerNet/england_epl/2014-2015/2015-02-21 - 18-00 Chelsea 1 - 1 Burnley
# total 37
# -rw------- 1 root root 37609 Jun  3 10:16 Labels-v2.json

# %%
import zipfile
import os

zip_file_path = "/content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/train.zip"
if os.path.exists(zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        print(f"Contents of {zip_file_path}:")
        for name in zip_ref.namelist()[:20]: # Stampa solo i primi 20 per brevità
            print(name)
else:
    print(f"Zip file not found: {zip_file_path}")
# Out:
# Contents of /content/gdrive/MyDrive/datasets/SoccerNet/spotting-OSL/ResNET_PCA512/train.zip:
# annotations.json
# spain_laliga/2014-2015/2015-02-21_-_18-00_Barcelona_0_-_1_Malaga/1_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-02-21_-_18-00_Barcelona_0_-_1_Malaga/2_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-02-22_-_23-00_Elche_0_-_2_Real_Madrid/1_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-02-22_-_23-00_Elche_0_-_2_Real_Madrid/2_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia/1_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-05-09_-_21-00_Real_Madrid_2_-_2_Valencia/2_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-05-17_-_20-00_Atl._Madrid_0_-_1_Barcelona/1_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-05-17_-_20-00_Atl._Madrid_0_-_1_Barcelona/2_ResNET_TF2_PCA512.npy
# spain_laliga/2014-2015/2015-05-17_-_20-00_Espanyol_1_-_4_Real_Madrid/1_ResNET_TF2_PCA512.npy
# ...
